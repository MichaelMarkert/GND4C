# %% [markdown]
# ## Querying for a person object
# Exemplary query structure for a person with three name elements, dOB and dOD

# %% [markdown]
# ### urllib version (Python 3)

# %%
import urllib.parse
import urllib.request
import time

url = 'https://lobid.org/gnd/reconcile/'

data = {'queries': '{"q0":{"query":"Philipp~ Heinrich~","type":"DifferentiatedPerson", "limit":100}, \
        "q1":{"query":"Philipp~ Heinrich~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}], "limit":100}, \
        "q2":{"query":"Philipp~ Heinrich~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q3":{"query":"Philipp~ Heinrich~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q4":{"query":"Heinrich~ Hopf~","type":"DifferentiatedPerson", "limit":100}, \
        "q5":{"query":"Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}], "limit":100}, \
        "q6":{"query":"Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q7":{"query":"Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100},\
        "q8":{"query":"Philipp~ Hopf~","type":"DifferentiatedPerson", "limit":100}, \
        "q9":{"query":"Philipp~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}], "limit":100}, \
        "q10":{"query":"Philipp~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q11":{"query":"Philipp~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q12":{"query":"Philipp~ Heinrich~ Hopf~","type":"DifferentiatedPerson", "limit":100}, \
        "q13":{"query":"Philipp~ Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}], "limit":100}, \
        "q14":{"query":"Philipp~ Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q15":{"query":"Philipp~ Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}}'}

encoded_data = urllib.parse.urlencode(data).encode('utf-8')

start_time = time.time()
request = urllib.request.Request(url, encoded_data)
response = urllib.request.urlopen(request)
end_time = time.time()

response_time = (end_time - start_time)
print(f"Response time: {response_time} seconds")
print(response.status)
#print(response.read())
# Out:
# Response time: 1.7906429767608643 seconds
# 200

# %% [markdown]
# ### requests version

# %%
import requests
import time

url = 'https://lobid.org/gnd/reconcile/'

# other reconciliation services do not work without tweaking the queries
#url = ' https://wikidata.reconci.link/en/api'

# Philipp Heinrich Hopf (1747–1804)
# query is all combinations of at least two name elements with queries for 1. name only, 2. name + dOB, 3. name + dOD, 4. name + dOB + dOD

data = {'queries': '{"q0":{"query":"Philipp~ Heinrich~","type":"DifferentiatedPerson", "limit":100}, \
        "q1":{"query":"Philipp~ Heinrich~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}], "limit":100}, \
        "q2":{"query":"Philipp~ Heinrich~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q3":{"query":"Philipp~ Heinrich~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q4":{"query":"Heinrich~ Hopf~","type":"DifferentiatedPerson", "limit":100}, \
        "q5":{"query":"Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}], "limit":100}, \
        "q6":{"query":"Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q7":{"query":"Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100},\
        "q8":{"query":"Philipp~ Hopf~","type":"DifferentiatedPerson", "limit":100}, \
        "q9":{"query":"Philipp~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}], "limit":100}, \
        "q10":{"query":"Philipp~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q11":{"query":"Philipp~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q12":{"query":"Philipp~ Heinrich~ Hopf~","type":"DifferentiatedPerson", "limit":100}, \
        "q13":{"query":"Philipp~ Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}], "limit":100}, \
        "q14":{"query":"Philipp~ Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfDeath","v":"1804"}], "limit":100}, \
        "q15":{"query":"Philipp~ Heinrich~ Hopf~","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}}'}

# it might be ok to query for all additional values in one q using OR as it gives the same result - but in case the limit is hit some results might be outside 
#data = {'queries': '{"q0":{"query":"Philipp Heinrich","type":"DifferentiatedPerson", "limit":100}, "q3":{"query":"Philipp Heinrich","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}, "q4":{"query":"Heinrich Hopf","type":"DifferentiatedPerson", "limit":100}, "q7":{"query":"Heinrich Hopf","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100},"q8":{"query":"Philipp Hopf","type":"DifferentiatedPerson", "limit":100}, "q11":{"query":"Philipp Hopf","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}, "q12":{"query":"Philipp Heinrich Hopf","type":"DifferentiatedPerson", "limit":100}, "q15":{"query":"Philipp Heinrich Hopf","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":100}}'}
#data = {'queries': '{"q3":{"query":"Philipp Heinrich","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":40}, "q7":{"query":"Heinrich Hopf","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":40}, "q11":{"query":"Philipp Hopf","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":40}, "q15":{"query":"Philipp Heinrich Hopf","type":"DifferentiatedPerson","properties":[{"pid":"dateOfBirth","v":"1747"}, {"pid":"dateOfDeath","v":"1804"}], "limit":40}}'}

# test for damerau-levenshtein
#data = {'queries': '{"q0":{"query":"Johann~ Adolp~ Sliovogt~", "limit":100}}'}

start_time = time.time()
response = requests.post(url, data=data)
end_time = time.time()

response_time = (end_time - start_time)
print(f"Response time: {response_time} seconds")
print(response.status_code)
#print(response.text)
# Out:
# Response time: 1.7163090705871582 seconds
# 200

# %% [markdown]
# ## Writing all GND-IDs to a list

# %%
import json

id_list = []
clean_list = []

data = json.loads(response.text)

for query in data:
    result_list = data[query]['result']
    for result in result_list:
        id_value = result['id']
        #print(f'["{query}"].result["{result_list.index(result)}"].id = {id_value}')
        id_list.append(id_value)
        
clean_list = list(set(id_list))
        
print("The responses contain " + str(len(clean_list)) + " (" + str(len(id_list)) + " if including duplicates)" + " elements in total.")
print(clean_list)
# Out:
# All responses contain 182(740 if counting duplicates) elements in total.
# ['122823400', '106907523X', '1067644539', '124438741', '136093272', '116989262', '1034903500', '123757304', '1083041762', '128361204', '128473363', '116082151', '120057476', '115387056', '102542236', '1113884657', '1102958778', '1052804624', '136740391', '119787121', '1038460417', '100358241', '1166822990', '1058351974', '1034669540', '13352325X', '124648010', '1106580141', '118705814', '136062660', '132747979', '1052431518', '1052462464', '1025280725', '12344117X', '108495175', '1035535882', '1016945108', '118565265', '116935413', '122445465', '118084658', '1050113985', '1161169342', '1053422377', '124191479', '1052725783', '132196867', '120588994', '1052714897', '1037516184', '106136190X', '131916866', '104304413', '134013492', '131723618', '122979540', '120702819', '1131285751', '1244416983', '1021396974', '101441928X', '121033104', '124648088', '1024826449', '142933732', '1220647233', '136642667', '1016608357', '118552392', '127357726', '1223062198', '102463530', '1104722860', '189548886', '132914786', '123469805', '116981342', '10307399X', '171877853', '124138403', '121772926', '128330414', '142528838', '133523284', '119264374', '1046188135', '1062202813', '134495357', '1079102884', '1076684491', '1055512004', '132320940', '129295043', '1037500296', '1186184833', '120823152', '1012273423', '130350443', '115661026', '12493143X', '132517574', '1221322125', '1031664386', '1043167579', '137730608', '1146807023', '1243960264', '1071219138', '118552406', '1169342191', '120709473', '1020588187', '11729912X', '137583788', '122781457', '14275482X', '136683924', '11874612X', '1052615473', '1042456542', '129162191', '1050968646', '1153236036', '1046868373', '12984716X', '1132668204', '1012780090', '13771579X', '100747280', '125543549', '1159016003', '120272563', '1071549693', '143220616', '102475881', '118583379', '1025832701', '1157858988', '1012389006', '1031429131', '1249714427', '122710606', '12138246X', '131583107', '1055526226', '140192263', '103511500X', '143942301', '1193942845', '1121548059', '1126771007', '1053517297', '134228022', '126789517', '173315321', '120223546', '1047600544', '130444626', '1146185588', '116028165', '123872707', '1018385444', '1162576081', '1055225102', '121502988', '1017368732', '128480386', '139066675', '1223489590', '1157875106', '1107814154', '120924064', '1164997904', '137715773', '1012273695', '14324308X', '1011992973', '1247763528', '1033719714', '1018302344', '1012273687']

# %% [markdown]
# ## Generating datasets via reconciliation_extend
# for all available properties see https://lobid.org/gnd/reconcile/properties?type=Person

# %%
import requests
import time

clean_list_string = ', '.join(['"{0}"'.format(x) for x in clean_list])

url = 'https://lobid.org/gnd/reconcile/'
data = {'extend':'{"ids":[' + clean_list_string + '],"properties":[\
{"id":"preferredName"},\
{"id":"variantName"},\
{"id":"dateOfBirth"},\
{"id":"placeOfBirth"},\
{"id":"dateOfDeath"},\
{"id":"placeOfDeath"},\
{"id":"professionOrOccupation"}]}'}

start_time = time.time()
response = requests.post(url, data=data)
end_time = time.time()

response_time = (end_time - start_time)
print(f"Response time: {response_time} seconds")
#print(response.status_code)
results = json.dumps(response.json(), indent=2) 
results = results.encode('utf-8').decode('unicode-escape')
print(results)
# Out:
# Response time: 2.168267011642456 seconds
# 200
# {
#   "meta": [
#     {
#       "id": "preferredName",
#       "name": "Bevorzugter Name"
#     },
#     {
#       "id": "variantName",
#       "name": "Varianter Name"
#     },
#     {
#       "id": "dateOfBirth",
#       "name": "Geburtsdatum"
#     },
#     {
#       "id": "placeOfBirth",
#       "name": "Geburtsort",
#       "type": {
#         "id": "PlaceOrGeographicName",
#         "name": "Geografikum"
#       }
#     },
#     {
#       "id": "dateOfDeath",
#       "name": "Sterbedatum"
#     },
#     {
#       "id": "placeOfDeath",
#       "name": "Sterbeort",
#       "type": {
#         "id": "PlaceOrGeographicName",
#         "name": "Geografikum"
#       }
#     },
#     {
#       "id": "professionOrOccupation",
#       "name": "Beruf oder Beschäftigung",
#       "type": {
#         "id": "SubjectHeading",
#         "name": "Schlagwort"
#       }
#     }
#   ],
#   "rows": {
#     "122823400": {
#       "preferredName": [
#         {
#           "str": "Eckestein, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Eckestein, Philippus Henricus"
#         },
#         {
#           "str": "Eckstein, Philipp Heinrich"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1653-08-03"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4024025-3",
#           "name": "Heilbronn"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1682-04-06"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4024025-3",
#           "name": "Heilbronn"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "106907523X": {
#       "preferredName": [
#         {
#           "str": "Kopf, Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Kopf, P."
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4032215-4",
#           "name": "Konstanz"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "7634571-3",
#           "name": "Ingenieur Biotechnologie"
#         }
#       ]
#     },
#     "1067644539": {
#       "preferredName": [
#         {
#           "str": "Reuss, Philipp Heinrich von"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Haberkorn-Reuss, Philippus Henricus de"
#         },
#         {
#           "str": "Haberkorn-Reuss, Philipp Heinrich von"
#         },
#         {
#           "str": "Reuss, Philippus Henricus de, dictus Haberkorn"
#         },
#         {
#           "str": "Reuss, Philippus Henricus de"
#         },
#         {
#           "str": "Philippus Henricus, de Reuss"
#         },
#         {
#           "str": "Philipp Heinrich, von Reuss"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "124438741": {
#       "preferredName": [
#         {
#           "str": "Gottfart, Philipp Heinrich von"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Gottfart, Philippus Heinricus a"
#         },
#         {
#           "str": "Geffort, ..."
#         },
#         {
#           "str": "Gottfart, Philippus Henricus a"
#         },
#         {
#           "str": "Göttfart, Philippus Heinricus a"
#         },
#         {
#           "str": "Göttfarth, Philip Heinrich von"
#         },
#         {
#           "str": "Göttfort, Philipp Heinrich von"
#         },
#         {
#           "str": "Gottfarth, Philipp Heinrich von"
#         },
#         {
#           "str": "Göttfordt, Philipp Heinrich von"
#         },
#         {
#           "str": "Göttfahrt, Philipp Heinrich von"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "136093272": {
#       "preferredName": [
#         {
#           "str": "Eichborn, Heinrich Philipp von"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Eichborn, Heinrich Philipp"
#         },
#         {
#           "str": "Moriz-Eichborn, Heinrich Philipp"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1844"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1926"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4140768-4",
#           "name": "Bankier"
#         }
#       ]
#     },
#     "116989262": {
#       "preferredName": [
#         {
#           "str": "Medem, Heinrich Philipp von"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1777"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1863"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1034903500": {
#       "preferredName": [
#         {
#           "str": "Hoff, Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1914-12-11"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1976-04-04"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4396366-3",
#           "name": "Kommunalpolitiker"
#         }
#       ]
#     },
#     "123757304": {
#       "preferredName": [
#         {
#           "str": "Hopf, Werner"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hopf, Werner H."
#         },
#         {
#           "str": "Hopf, Werner Heinrich"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1944-10-08"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "2019-08-18"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1083041762": {
#       "preferredName": [
#         {
#           "str": "ImHoof, Johann Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "ImHoof, Johannes Henricus"
#         },
#         {
#           "str": "ImHoof, Joh. Henricus"
#         },
#         {
#           "str": "Hoof, Johann Heinrich im"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "128361204": {
#       "preferredName": [
#         {
#           "str": "Wolff, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Wolff, P. H."
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1822-06-15"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4536853-3",
#           "name": "Affoltern (Zürich)"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1903-10-05"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4683917-3",
#           "name": "Weiningen (Kanton Zürich)"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4132592-8",
#           "name": "Pfarrer"
#         },
#         {
#           "id": "7635523-8",
#           "name": "Tierschützer"
#         }
#       ]
#     },
#     "128473363": {
#       "preferredName": [
#         {
#           "str": "Braunschmid, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Braunschmidius, Philippus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "116082151": {
#       "preferredName": [
#         {
#           "str": "Perrenon, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Perrenon, Philipp Heinr."
#         },
#         {
#           "str": "Perrenon, Philippus Henricus"
#         },
#         {
#           "str": "Perrenonius, Philippus Henricus"
#         },
#         {
#           "str": "Perrenon, Phil. Heinr."
#         },
#         {
#           "str": "Perrenon, Philippe Henry"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4138343-6",
#           "name": "Verleger"
#         },
#         {
#           "id": "4130948-0",
#           "name": "Buchhändler"
#         }
#       ]
#     },
#     "120057476": {
#       "preferredName": [
#         {
#           "str": "Simon, Philipp Heinrich Friedrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Simon, Philipp H."
#         },
#         {
#           "str": "Simon, Philippus Henricus Fridericus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "115387056": {
#       "preferredName": [
#         {
#           "str": "Henke, Heinrich Philipp Conrad"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Henke, H. P. C."
#         },
#         {
#           "str": "Henke, Henricus Philippus Conradus"
#         },
#         {
#           "str": "Hencke, Henricus Philippus Conradus"
#         },
#         {
#           "str": "Hencke, Heinrich Philipp Conrad"
#         },
#         {
#           "str": "Henke, Heinrich Philipp Konrad"
#         },
#         {
#           "str": "Henke, Heinrich P."
#         },
#         {
#           "str": "Henke, Heinrich Philipp"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1752-07-03"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4527347-9",
#           "name": "Hehlen"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1809-05-02"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4024344-8",
#           "name": "Helmstedt"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4398113-6",
#           "name": "Kirchenhistoriker"
#         },
#         {
#           "id": "4025243-7",
#           "name": "Hochschullehrer"
#         },
#         {
#           "id": "4015882-2",
#           "name": "Evangelischer Theologe"
#         }
#       ]
#     },
#     "102542236": {
#       "preferredName": [
#         {
#           "str": "Kreuser, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Kreuser, Philipp H."
#         },
#         {
#           "str": "Kreuser, Philippus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1726-05-28"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "7756030-9",
#           "name": "Dettingen an der Erms (Region)"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1796-03-19"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4095600-3",
#           "name": "Holzmaden"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4132592-8",
#           "name": "Pfarrer"
#         }
#       ]
#     },
#     "1113884657": {
#       "preferredName": [
#         {
#           "str": "Pickert, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1849-07-22"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4024469-6",
#           "name": "Herdecke"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4003157-3",
#           "name": "Arzt"
#         }
#       ]
#     },
#     "1102958778": {
#       "preferredName": [
#         {
#           "str": "Goldhagen, Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Goldhagen, Henricus Philippus"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1746-04-11"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4042532-0",
#           "name": "Nordhausen"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1826-04-30"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4023025-9",
#           "name": "Halle (Saale)"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         },
#         {
#           "id": "4127948-7",
#           "name": "Schulleiter"
#         },
#         {
#           "id": "4398835-0",
#           "name": "Stadtsyndikus"
#         },
#         {
#           "id": "4177008-0",
#           "name": "Ratsherr"
#         },
#         {
#           "id": "4123227-6",
#           "name": "Freimaurer"
#         }
#       ]
#     },
#     "1052804624": {
#       "preferredName": [
#         {
#           "str": "Zopf, Heinrich Christian"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Zopfius, Henricus Christianus"
#         },
#         {
#           "str": "Zopfius, Heinricus Christianus"
#         },
#         {
#           "str": "Zopff, Heinrich Christian"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1693"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4020295-1",
#           "name": "Gera"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "136740391": {
#       "preferredName": [
#         {
#           "str": "Hoff, Norman-Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, Norman"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4003157-3",
#           "name": "Arzt"
#         }
#       ]
#     },
#     "119787121": {
#       "preferredName": [
#         {
#           "str": "Philipp, Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1038460417": {
#       "preferredName": [
#         {
#           "str": "Bila, Philipp Heinrich von"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Bila, Philipp Heinrichen von"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "100358241": {
#       "preferredName": [
#         {
#           "str": "Hoff, Heinrich Georg"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, J. G."
#         },
#         {
#           "str": "Hoff, H. G."
#         },
#         {
#           "str": "Hoff, I. G."
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4053309-8",
#           "name": "Schriftsteller"
#         }
#       ]
#     },
#     "1166822990": {
#       "preferredName": [
#         {
#           "str": "Fürstenberger, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1695-09-10"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1756-12-03"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4128272-3",
#           "name": "Kaufmann"
#         }
#       ]
#     },
#     "1058351974": {
#       "preferredName": [
#         {
#           "str": "Hoff, Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1947"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4063504-1",
#           "name": "Viersen"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4045968-8",
#           "name": "Physiker"
#         }
#       ]
#     },
#     "1034669540": {
#       "preferredName": [
#         {
#           "str": "Baetzendorf, Philipp Georg Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1715-06-04"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "13352325X": {
#       "preferredName": [
#         {
#           "str": "Zopf, Johann Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Zopfius, Joannes Henricus"
#         },
#         {
#           "str": "Zopfius, Iohannes Henricus"
#         },
#         {
#           "str": "Zopfius, Johannes Henricus"
#         },
#         {
#           "str": "Zopf, Johannes Heinrich"
#         },
#         {
#           "str": "Zopff, Joannes Henricus"
#         },
#         {
#           "str": "Zopff, Johannes Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1724"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4021972-0",
#           "name": "Greiz"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1771"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4003157-3",
#           "name": "Arzt"
#         }
#       ]
#     },
#     "124648010": {
#       "preferredName": [
#         {
#           "str": "Kopf, Christoph Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Kopf, Christophorus Philippus"
#         },
#         {
#           "str": "Kopf, Christo. Phil."
#         },
#         {
#           "str": "Kopfius, Christophorus Philippus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "1106580141": {
#       "preferredName": [
#         {
#           "str": "Weiß von Limpurg, Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Weiß von Limpurg, im Basler Hof, Philipp"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1557-07-18"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4018118-2",
#           "name": "Frankfurt am Main"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1594-07-16"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4018118-2",
#           "name": "Frankfurt am Main"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4177008-0",
#           "name": "Ratsherr"
#         }
#       ]
#     },
#     "118705814": {
#       "preferredName": [
#         {
#           "str": "Hoff, Jacobus H. van't"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, Jakob Heinrich van't"
#         },
#         {
#           "str": "Van'tHoff, Jacobus Henricus"
#         },
#         {
#           "str": "Hoff, Jacobus Henrikus van't"
#         },
#         {
#           "str": "Hoff, Jacob Heinrich van't"
#         },
#         {
#           "str": "Van'tHoff, Jakob H."
#         },
#         {
#           "str": "Hoff, Jacobus Henricus van't"
#         },
#         {
#           "str": "'tHoff, Jacobus Henricus van"
#         },
#         {
#           "str": "Van'tHoff, Hendrikus Jakobus"
#         },
#         {
#           "str": "'t Hoff, Jacobus Henricus van"
#         },
#         {
#           "str": "Goff, Jakob Gendrik Vant-"
#         },
#         {
#           "str": "Hoff, J.H. van't"
#         },
#         {
#           "str": "Vant-Goff, Ja. G."
#         },
#         {
#           "str": "Van'tHoff, Jakob Heinrich"
#         },
#         {
#           "str": "Hoff, J. H. van't"
#         },
#         {
#           "str": "Van't Hoff, Jacobus H."
#         },
#         {
#           "str": "Vant-Goff, Jakob G."
#         },
#         {
#           "str": "Van't Hoff, Jacobus Henricus"
#         },
#         {
#           "str": "Hoff, Jacobus H."
#         },
#         {
#           "str": "Hoff, Jan van"
#         },
#         {
#           "str": "Van't Hoff, Hendrikus Jakobus"
#         },
#         {
#           "str": "Hoff, Jacobus Hendricus van't"
#         },
#         {
#           "str": "Hoff, Jacobus Henricus"
#         },
#         {
#           "str": "Vant-Goff, Jakob Gendrik"
#         },
#         {
#           "str": "Van't Hoff, Jacob H."
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1852-08-30"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4050739-7",
#           "name": "Rotterdam"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1911-03-01"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4112721-3",
#           "name": "Berlin-Steglitz"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4009836-9",
#           "name": "Chemiker"
#         },
#         {
#           "id": "4042421-2",
#           "name": "Nobelpreisträger"
#         }
#       ]
#     },
#     "136062660": {
#       "preferredName": [
#         {
#           "str": "Kleinschmidt, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1701"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1731"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "132747979": {
#       "preferredName": [
#         {
#           "str": "Hopfe, Heinrich Christian Ludwig"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hopfe, Henricus Christianus Ludovicus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4022987-7",
#           "name": "Halberstadt"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1052431518": {
#       "preferredName": [
#         {
#           "str": "Koepf, Karl Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Koepf, Karl H."
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1930-09-05"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1990-12-03"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4002844-6",
#           "name": "Architekt"
#         },
#         {
#           "id": "4033654-2",
#           "name": "Kunsthistoriker"
#         },
#         {
#           "id": "4345132-9",
#           "name": "Konservator"
#         }
#       ]
#     },
#     "1052462464": {
#       "preferredName": [
#         {
#           "str": "Pistorius, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Pistorius, Philippus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4003157-3",
#           "name": "Arzt"
#         }
#       ]
#     },
#     "1025280725": {
#       "preferredName": [
#         {
#           "str": "Hoff, Heinrich Leonhard Emanuel von"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1868"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1941"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4664235-3",
#           "name": "Generalmajor"
#         }
#       ]
#     },
#     "12344117X": {
#       "preferredName": [
#         {
#           "str": "Heinisch, Philipp"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1945"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         },
#         {
#           "id": "4048755-6",
#           "name": "Rechtsanwalt"
#         },
#         {
#           "id": "4232470-1",
#           "name": "Karikaturist"
#         }
#       ]
#     },
#     "108495175": {
#       "preferredName": [
#         {
#           "str": "Cappe, Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Cappe, H. Ph."
#         },
#         {
#           "str": "Cappe, Heinrich P."
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1862"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4172176-7",
#           "name": "Numismatiker"
#         }
#       ]
#     },
#     "1035535882": {
#       "preferredName": [
#         {
#           "str": "Hänsel, Philipp Heinrich Friedrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1779-07-09"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4035206-7",
#           "name": "Leipzig"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1849-08-05"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4049923-6",
#           "name": "Richter"
#         }
#       ]
#     },
#     "1016945108": {
#       "preferredName": [
#         {
#           "str": "Rapp, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1723"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1783"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4221401-4",
#           "name": "Händler"
#         }
#       ]
#     },
#     "118565265": {
#       "preferredName": [
#         {
#           "str": "Kopf, Hinrich Wilhelm"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Kopf, H. W."
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1893-05-06"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4715995-9",
#           "name": "Neuenkirchen (Landkreis Cuxhaven)"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1961-12-21"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4021477-1",
#           "name": "Göttingen"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         },
#         {
#           "id": "4046517-2",
#           "name": "Politiker"
#         },
#         {
#           "id": "4034399-6",
#           "name": "Landwirt"
#         },
#         {
#           "id": "4128272-3",
#           "name": "Kaufmann"
#         }
#       ]
#     },
#     "116935413": {
#       "preferredName": [
#         {
#           "str": "Hoff, Carl Heinrich, der Ältere"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, Karl Heinrich"
#         },
#         {
#           "str": "Hoff, Carl Heinrich"
#         },
#         {
#           "str": "Hoff, Carl"
#         },
#         {
#           "str": "Hoff, Karl"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1838-09-08"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4037372-1",
#           "name": "Mannheim"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1890-05-13"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4029713-5",
#           "name": "Karlsruhe"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4037215-7",
#           "name": "Maler"
#         },
#         {
#           "id": "4053309-8",
#           "name": "Schriftsteller"
#         }
#       ]
#     },
#     "122445465": {
#       "preferredName": [
#         {
#           "str": "Hadamar, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hadamar, Ph. Heinrich"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "118084658": {
#       "preferredName": [
#         {
#           "str": "Wiering, Philipp Jakob Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Wiering, Philipp Jacob Heinrich"
#         },
#         {
#           "str": "Wiering, Philippus Jacobus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {
#           "id": "1137861088",
#           "name": "Börry"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "1050113985": {
#       "preferredName": [
#         {
#           "str": "Löw, Johann Heinrich, Witwe"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Löwische Wittwe"
#         },
#         {
#           "str": "Lion, Veuve"
#         },
#         {
#           "str": "Löwe, J. H., Witwe"
#         },
#         {
#           "str": "Vidua Loewiana"
#         },
#         {
#           "str": "Loew, Johann Heinrich, Witwe"
#         },
#         {
#           "str": "Löwe, Joh. Heinrich, Witwe"
#         },
#         {
#           "str": "J. Heinr. Löwens seel. Hochs. S. Hof-Buchdr. hinterl. Wittwe"
#         },
#         {
#           "str": "Löwe, Johann Heinrich, Witwe"
#         },
#         {
#           "str": "Löwe, Witwe"
#         },
#         {
#           "str": "Löwische Witwe"
#         },
#         {
#           "str": "Löwe, Johann Heinr., Witwe"
#         },
#         {
#           "str": "J. H. Löwens sel. hinterl. Wittwe"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4013091-5",
#           "name": "Drucker"
#         },
#         {
#           "id": "4266720-3",
#           "name": "Verlegerin"
#         }
#       ]
#     },
#     "1161169342": {
#       "preferredName": [
#         {
#           "str": "Hoff, Paul"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, Heinrich Max Paul"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1867-12-15"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1928-01-20"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1053422377": {
#       "preferredName": [
#         {
#           "str": "Hoff, Johann Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, Johannes Heinrich"
#         },
#         {
#           "str": "Hoff, Joannes Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "124191479": {
#       "preferredName": [
#         {
#           "str": "Linden, Carl Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Linden, Karl Philipp Heinrich"
#         },
#         {
#           "str": "Linden, Car. Philip. Henr."
#         },
#         {
#           "str": "Linden, Carolus Philippus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4003157-3",
#           "name": "Arzt"
#         }
#       ]
#     },
#     "1052725783": {
#       "preferredName": [
#         {
#           "str": "Frommann, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Frommann, Philippus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "7540658-5",
#           "name": "Respondent"
#         }
#       ]
#     },
#     "132196867": {
#       "preferredName": [
#         {
#           "str": "Hopfe, Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hopfe, Philippus"
#         },
#         {
#           "str": "Hopf, Philipp"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "120588994": {
#       "preferredName": [
#         {
#           "str": "Ward, Josephine Mary Hope-Scott"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Ward, Wilfrid Philip, Mrs."
#         },
#         {
#           "str": "Scott Ward, Josephine Mary Hope-"
#         },
#         {
#           "str": "Hope-Scott Ward, Josephine Mary"
#         },
#         {
#           "str": "Ward, Wilfrid, Mrs."
#         },
#         {
#           "str": "Hope-Scott, Josephine Mary"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1864"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1932-11-21"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4074335-4",
#           "name": "London"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4053311-6",
#           "name": "Schriftstellerin"
#         }
#       ]
#     },
#     "1052714897": {
#       "preferredName": [
#         {
#           "str": "Besson, Philipp Karl Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Besson, Philippus Carolus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1037516184": {
#       "preferredName": [
#         {
#           "str": "Kopf, Arnold Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Kopffius, Arnoldus-Philippus"
#         },
#         {
#           "str": "Kopf, Arpold-Philipp"
#         },
#         {
#           "str": "Kopffius, Arpoldus-Philippus"
#         },
#         {
#           "str": "Kopfius, Arnoldus-Philippus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4138343-6",
#           "name": "Verleger"
#         }
#       ]
#     },
#     "106136190X": {
#       "preferredName": [
#         {
#           "str": "Hoff, Philipp von"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4402399-6",
#           "name": "Aufnahmeleiter"
#         }
#       ]
#     },
#     "131916866": {
#       "preferredName": [
#         {
#           "str": "Hattorff, Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hattorff, Henrich Philip"
#         },
#         {
#           "str": "Hattorf, Heinrich Philipp"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1630"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1687"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "104304413": {
#       "preferredName": [
#         {
#           "str": "Zopff, Johann Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Zopf, Johann Heinrich"
#         },
#         {
#           "str": "Zopff, Johannes Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "134013492": {
#       "preferredName": [
#         {
#           "str": "Kirchner, Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Kirchner, Henrich Philipp"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "131723618": {
#       "preferredName": [
#         {
#           "str": "Hopff, Heinrich Wilhelm"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hopff, Henricus Guilelmus"
#         },
#         {
#           "str": "Hopff, Henr. Wilh."
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1840-03-14"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "122979540": {
#       "preferredName": [
#         {
#           "str": "Usler, Heinrich Philipp von"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Usler, Henricus Philippus ab"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "120702819": {
#       "preferredName": [
#         {
#           "str": "Zopf, Heinrich Ludwig"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Zopf, Henricus Ludovicus"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1801"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1131285751": {
#       "preferredName": [
#         {
#           "str": "Zopf, Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Zopf, Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4020295-1",
#           "name": "Gera"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4059763-5",
#           "name": "Theologiestudent"
#         }
#       ]
#     },
#     "1244416983": {
#       "preferredName": [
#         {
#           "str": "Głowan, Hendrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Kopf, Heinrich"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1833-10-20"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1884-11-01"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4176310-5",
#           "name": "Publizist"
#         },
#         {
#           "id": "4035088-5",
#           "name": "Lehrer"
#         },
#         {
#           "id": "4061414-1",
#           "name": "Übersetzer"
#         }
#       ]
#     },
#     "1021396974": {
#       "preferredName": [
#         {
#           "str": "Hoff, Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, H."
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1774-03-11"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4005728-8",
#           "name": "Berlin"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4053309-8",
#           "name": "Schriftsteller"
#         },
#         {
#           "id": "4434147-7",
#           "name": "Privatier"
#         }
#       ]
#     },
#     "101441928X": {
#       "preferredName": [
#         {
#           "str": "Beuttel, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Beuttelius, Philippus Henricus"
#         },
#         {
#           "str": "Beuttel, Philippus H."
#         },
#         {
#           "str": "Beuttel, Philippus Henricus"
#         },
#         {
#           "str": "Beuttel, Philip. Henric."
#         },
#         {
#           "str": "Beutel, Philipp Heinrich"
#         },
#         {
#           "str": "Beuttel, Philipp H."
#         },
#         {
#           "str": "B., P. H."
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4003157-3",
#           "name": "Arzt"
#         }
#       ]
#     },
#     "121033104": {
#       "preferredName": [
#         {
#           "str": "Orth, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Ortth, Philipp Heinrich"
#         },
#         {
#           "str": "Orth, Philippus Henricus"
#         },
#         {
#           "str": "Orth, P. H.."
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "124648088": {
#       "preferredName": [
#         {
#           "str": "Kopf, Christoph Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Kopfius, Christophorus Philippus"
#         },
#         {
#           "str": "Kopf, Christophorus Philippus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "1024826449": {
#       "preferredName": [
#         {
#           "str": "Philipp, Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1865-02-08"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4240723-0",
#           "name": "Aschaffenburg-Damm"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1928-07-17"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4042742-0",
#           "name": "Nürnberg"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4049923-6",
#           "name": "Richter"
#         },
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "142933732": {
#       "preferredName": [
#         {
#           "str": "Stenglin, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Stenglin, Pilipp Hinrich"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1688"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1757"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1220647233": {
#       "preferredName": [
#         {
#           "str": "Tilemann, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1665-12-17"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4012326-1",
#           "name": "Dillenburg"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1742-02-06"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4132592-8",
#           "name": "Pfarrer"
#         }
#       ]
#     },
#     "136642667": {
#       "preferredName": [
#         {
#           "str": "Philipp, Heinrich Nicol"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1769"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "1054785333",
#           "name": "Seibis"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1840"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "1054785333",
#           "name": "Seibis"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4032009-1",
#           "name": "Komponist"
#         },
#         {
#           "id": "4035088-5",
#           "name": "Lehrer"
#         },
#         {
#           "id": "4604119-9",
#           "name": "Arrangeur"
#         }
#       ]
#     },
#     "1016608357": {
#       "preferredName": [
#         {
#           "str": "Kalkmann, Heinrich Philipp Ludwig"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1822-04-30"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4008135-7",
#           "name": "Bremen"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1873-05-01"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4066043-6",
#           "name": "Wiesbaden"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4128272-3",
#           "name": "Kaufmann"
#         },
#         {
#           "id": "4165110-8",
#           "name": "Konsul"
#         },
#         {
#           "id": "4061949-7",
#           "name": "Unternehmer"
#         }
#       ]
#     },
#     "118552392": {
#       "preferredName": [
#         {
#           "str": "Hoff, Ferdinand"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, Ferdinand Hans Hinrich"
#         }
#       ],
# ...
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1774"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1839"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1162576081": {
#       "preferredName": [
#         {
#           "str": "Koch, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Koch, Philipp Henricus"
#         },
#         {
#           "str": "Koch, Philippus Heinrich"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1683"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "16052043-5",
#           "name": "Ryn"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1725-09-05"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4132592-8",
#           "name": "Pfarrer"
#         },
#         {
#           "id": "4158589-6",
#           "name": "Gymnasiallehrer"
#         }
#       ]
#     },
#     "1055225102": {
#       "preferredName": [
#         {
#           "str": "Hopf, Wilhelm"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hopf, Heinrich Wilhelm Leonard"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1842-10-12"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "16091960-5",
#           "name": "Schenklengsfeld-Wippershain"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1921-03-16"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4038563-2",
#           "name": "Melsungen"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4132592-8",
#           "name": "Pfarrer"
#         },
#         {
#           "id": "4059756-8",
#           "name": "Theologe"
#         }
#       ]
#     },
#     "121502988": {
#       "preferredName": [
#         {
#           "str": "Zopf, Johann Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Zopfens, Johann Heinrich"
#         },
#         {
#           "str": "Zopf, Johann Friedrich"
#         },
#         {
#           "str": "Zopf, Joan. Henricus"
#         },
#         {
#           "str": "Zopfius, Johannes H."
#         },
#         {
#           "str": "Zopf, Johannes Heinrich"
#         },
#         {
#           "str": "Zopfius, Joannes H."
#         },
#         {
#           "str": "Zopff, Johann Friedrich"
#         },
#         {
#           "str": "Zopfius, Joan. Henricus"
#         },
#         {
#           "str": "Zopff, Johann Heinrich"
#         },
#         {
#           "str": "Zopfius, Joannes Henricus"
#         },
#         {
#           "str": "Zopfens, Johann H."
#         },
#         {
#           "str": "Zopfius, Johannes Henricus"
#         },
#         {
#           "str": "Zopfen, Johann H."
#         },
#         {
#           "str": "Zopf, Johann H."
#         },
#         {
#           "str": "Zopf, Joh. Heinrich"
#         },
#         {
#           "str": "Zopf, Joannes Henricus"
#         },
#         {
#           "str": "Zopfen, Johann Heinrich"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1691-04-06"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4020295-1",
#           "name": "Gera"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1774-02-01"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4015557-2",
#           "name": "Essen"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4025098-2",
#           "name": "Historiker"
#         },
#         {
#           "id": "4130322-2",
#           "name": "Prediger"
#         },
#         {
#           "id": "4015882-2",
#           "name": "Evangelischer Theologe"
#         },
#         {
#           "id": "4053309-8",
#           "name": "Schriftsteller"
#         },
#         {
#           "id": "4158589-6",
#           "name": "Gymnasiallehrer"
#         }
#       ]
#     },
#     "1017368732": {
#       "preferredName": [
#         {
#           "str": "Hopp, Philipp"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1977"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4131826-2",
#           "name": "Biologe"
#         }
#       ]
#     },
#     "128480386": {
#       "preferredName": [
#         {
#           "str": "Dancklufft, Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Dancklufft, Heinricus Philippus"
#         },
#         {
#           "str": "Dancklufft, Henricus Philippus"
#         },
#         {
#           "str": "Dankluft, Heinrich Philipp"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4001409-5",
#           "name": "Altenburg (Thüringen)"
#         }
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "139066675": {
#       "preferredName": [
#         {
#           "str": "Steinrück, Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Steinruck, Heinrich Philipp"
#         },
#         {
#           "str": "Steinruckius, Henricus Philippus"
#         },
#         {
#           "str": "Steinrück, Heinrich Philip"
#         },
#         {
#           "str": "Steinruck, Heinrich Philip"
#         },
#         {
#           "str": "Steinrück, Henricus Philippus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4210801-9",
#           "name": "Hofprediger"
#         },
#         {
#           "id": "4132592-8",
#           "name": "Pfarrer"
#         }
#       ]
#     },
#     "1223489590": {
#       "preferredName": [
#         {
#           "str": "Hopf, Johann Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1668"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4025565-7",
#           "name": "Hohenstaufen"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1725-04-06"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4062257-5",
#           "name": "Vaihingen an der Enz"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4149467-2",
#           "name": "Diakon"
#         },
#         {
#           "id": "4132592-8",
#           "name": "Pfarrer"
#         }
#       ]
#     },
#     "1157875106": {
#       "preferredName": [
#         {
#           "str": "Brandt, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Brandt, Philippus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1107814154": {
#       "preferredName": [
#         {
#           "str": "Köhler, Philipp Friedrich Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Köhler, Heinrich"
#         },
#         {
#           "str": "Koehler, Philipp Friedrich Heinrich"
#         },
#         {
#           "str": "Köhler, Henricus"
#         },
#         {
#           "str": "Koehler, Philipp Heinrich"
#         },
#         {
#           "str": "Koehler, Henricus"
#         },
#         {
#           "str": "Köhler, Friedrich Heinrich"
#         },
#         {
#           "str": "Koehler, Friedrich Heinrich"
#         },
#         {
#           "str": "Köhler, Philipp Heinrich"
#         },
#         {
#           "str": "Koehler, Heinrich"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1772-05-10"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4025879-8",
#           "name": "Hornberg (Ortenaukreis)"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1820-02"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4004380-0",
#           "name": "Baltimore, Md."
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4003157-3",
#           "name": "Arzt"
#         }
#       ]
#     },
#     "120924064": {
#       "preferredName": [
#         {
#           "str": "Im Hof-Spielberg, Alexander"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Imhof-Spielberg, Alexander von"
#         },
#         {
#           "str": "Hof-Spiegelberg, Alexander im"
#         },
#         {
#           "str": "Imhof von und zu Spielberg und Oberschwammbach, Alexander Joseph Anton Philipp"
#         },
#         {
#           "str": "Spiegelberg, Alexander ImHof-"
#         },
#         {
#           "str": "Imhoff-Spielberg, Alexander von"
#         },
#         {
#           "str": "Im Hof Spiegelberg, Alexander"
#         },
#         {
#           "str": "ImHof-Spiegelberg, Alexander"
#         },
#         {
#           "str": "Spielberg und Oberschwammbach, Alexander Joseph Anton Philipp Imhof von und zu"
#         },
#         {
#           "str": "Spielberg und Oberschwambach, Alexander Joseph Anton Philipp Imhof von und zu"
#         },
#         {
#           "str": "ImHof Spiegelberg, Alexander"
#         },
#         {
#           "str": "Oberschwambach, Alexander Joseph Anton Philipp von und zu Spielberg und"
#         },
#         {
#           "str": "Oberschwammbach, Alexander Joseph Anton Philipp von und zu Spielberg und"
#         },
#         {
#           "str": "Imhof, Alexander Joseph Anton Philipp von und zu Spielberg und Oberschwammbach"
#         },
#         {
#           "str": "Imhof, Alexander Joseph Anton Philipp von und zu Spielberg und Oberschwambach"
#         },
#         {
#           "str": "Imhof von und zu Spielberg und Oberschwambach, Alexander Joseph Anton Philipp"
#         },
#         {
#           "str": "Imhof, Alexander von"
#         },
#         {
#           "str": "Imhoff, Alexander von"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1766"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1822"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4460674-6",
#           "name": "Hofbeamter"
#         },
#         {
#           "id": "4175450-5",
#           "name": "Postbeamter"
#         },
#         {
#           "id": "4053309-8",
#           "name": "Schriftsteller"
#         },
#         {
#           "id": "4156312-8",
#           "name": "Geheimer Rat"
#         }
#       ]
#     },
#     "1164997904": {
#       "preferredName": [
#         {
#           "str": "Recken, Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Recken, Henricus Philippus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4030020-1",
#           "name": "Katholischer Theologe"
#         }
#       ]
#     },
#     "137715773": {
#       "preferredName": [
#         {
#           "str": "Karcher, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1776"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1850"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4128272-3",
#           "name": "Kaufmann"
#         },
#         {
#           "id": "4061949-7",
#           "name": "Unternehmer"
#         }
#       ]
#     },
#     "1012273695": {
#       "preferredName": [
#         {
#           "str": "Hoff, Karl Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hoff, K."
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1866-08-17"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4013255-9",
#           "name": "Düsseldorf"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1904"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4037215-7",
#           "name": "Maler"
#         },
#         {
#           "id": "4033423-5",
#           "name": "Künstler"
#         }
#       ]
#     },
#     "14324308X": {
#       "preferredName": [
#         {
#           "str": "Caspari, Philipp Heinrich"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Caspari, Philippus Henricus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4169229-9",
#           "name": "Medizinstudent"
#         }
#       ]
#     },
#     "1011992973": {
#       "preferredName": [
#         {
#           "str": "Fenner, Johann Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Fenner, Johannes Henricus Philippus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4058167-6",
#           "name": "Student"
#         }
#       ]
#     },
#     "1247763528": {
#       "preferredName": [
#         {
#           "str": "Heinrichs, Philipp"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4029050-5",
#           "name": "Jurist"
#         }
#       ]
#     },
#     "1033719714": {
#       "preferredName": [
#         {
#           "str": "Ast, Heinrich Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Ast, Heinrich"
#         },
#         {
#           "str": "Schäfer Ast"
#         }
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1848-04-04"
#         }
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1921-08-15"
#         }
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1018302344": {
#       "preferredName": [
#         {
#           "str": "Hof, Johann Philipp"
#         }
#       ],
#       "variantName": [
#         {
#           "str": "Hofius, Johannes Philippus"
#         }
#       ],
#       "dateOfBirth": [
#         {}
#       ],
#       "placeOfBirth": [
#         {}
#       ],
#       "dateOfDeath": [
#         {}
#       ],
#       "placeOfDeath": [
#         {}
#       ],
#       "professionOrOccupation": [
#         {}
#       ]
#     },
#     "1012273687": {
#       "preferredName": [
#         {
#           "str": "Hoff, Karl Heinrich"
#         }
#       ],
#       "variantName": [
#         {}
#       ],
#       "dateOfBirth": [
#         {
#           "str": "1804-07-12"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "4037372-1",
#           "name": "Mannheim"
#         }
#       ],
#       "dateOfDeath": [
#         {
#           "str": "1891-05-07"
#         }
#       ],
#       "placeOfDeath": [
#         {
#           "id": "4037372-1",
#           "name": "Mannheim"
#         }
#       ],
#       "professionOrOccupation": [
#         {
#           "id": "4046517-2",
#           "name": "Politiker"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# ## Alternative: Generating datasets from regular lobidAPI - needs one request per GND-ID

# %%
results_dict = {"member": []}
for gnd in clean_list:
    url = 'http://lobid.org/gnd/' + gnd + '.json'
    response = requests.get(url).json()
    results_dict["member"].append(response)

results_dict = json.dumps(results_dict, indent=2) 
results_dict = results_dict.encode('utf-8').decode('unicode-escape')
#print(results_dict)
# Out:
# {
#   "member": [
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4029050-5",
#           "label": "Jurist"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "https://d-nb.info/gnd/4024025-3",
#           "label": "Heilbronn"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "dateOfDeath": [
#         "1682-04-06"
#       ],
#       "dateOfBirth": [
#         "1653-08-03"
#       ],
#       "placeOfDeath": [
#         {
#           "id": "https://d-nb.info/gnd/4024025-3",
#           "label": "Heilbronn"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Philippus Henricus"
#           ],
#           "surname": [
#             "Eckestein"
#           ]
#         },
#         {
#           "forename": [
#             "Philipp Heinrich"
#           ],
#           "surname": [
#             "Eckstein"
#           ]
#         }
#       ],
#       "type": [
#         "AuthorityResource",
#         "Person",
#         "DifferentiatedPerson"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)122823400"
#       ],
#       "biographicalOrHistoricalInformation": [
#         "aus Heilbronn/Neckar; Jurist"
#       ],
#       "periodOfActivity": [
#         "1672-1675"
#       ],
#       "academicDegree": [
#         "Lic. jur."
#       ],
#       "publication": [
#         "Bardili, Burckhard: Conclusionum Theoretico-Practicarum Exercitatio XXXVIII. De Poenis. - 1672",
#         "Katalog der fürstlich Stolberg-Stolberg'schen Leichenpredigten-Sammlung. Bd. 1. - 1927",
#         "Bardili, Burckhard: De divortio ex causa desertionis. - 1675"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/122823400/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2011-07-22T22:41:38.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplinäre Allgemeinwörter"
#         }
#       },
#       "gndIdentifier": "122823400",
#       "id": "https://d-nb.info/gnd/122823400",
#       "preferredName": "Eckestein, Philipp Heinrich",
#       "variantName": [
#         "Eckestein, Philippus Henricus",
#         "Eckstein, Philipp Heinrich"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Philipp Heinrich"
#         ],
#         "surname": [
#           "Eckestein"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://id.loc.gov/rwo/agents/nr2001022174",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q13219454",
#             "abbr": "LC",
#             "publisher": "Library of Congress",
#             "icon": "http://www.loc.gov/favicon.ico",
#             "name": "NACO Authority File"
#           }
#         },
#         {
#           "id": "http://isni.org/isni/0000000053035435",
#           "collection": {
#             "id": "http://isni.org"
#           }
#         },
#         {
#           "id": "http://viaf.org/viaf/35348020",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "id": "http://www.wikidata.org/entity/Q55676083",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q2013",
#             "abbr": "WIKIDATA",
#             "publisher": "Wikimedia Foundation Inc.",
#             "icon": "https://www.wikidata.org/static/favicon/wikidata.ico",
#             "name": "Wikidata"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/122823400/about"
#         },
#         {
#           "collection": {
#             "abbr": "DDB",
#             "name": "Deutsche Digitale Bibliothek",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "id": "http://www.wikidata.org/entity/Q621630"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/122823400"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/7634571-3",
#           "label": "Ingenieur Biotechnologie"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "https://d-nb.info/gnd/4032215-4",
#           "label": "Konstanz"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "P."
#           ],
#           "surname": [
#             "Kopf"
#           ]
#         }
#       ],
#       "type": [
#         "Person",
#         "AuthorityResource",
#         "DifferentiatedPerson"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "academicDegree": [
#         "Dr.-Ing."
#       ],
#       "publication": [
#         "Modellierung der Staubfiltration auf Mikro- und Makroebene unter dem Einfluss komplexer Berandungen"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/106907523X/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2016-08-11T10:47:50.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         }
#       },
#       "gndIdentifier": "106907523X",
#       "id": "https://d-nb.info/gnd/106907523X",
#       "preferredName": "Kopf, Philipp",
#       "variantName": [
#         "Kopf, P."
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Philipp"
#         ],
#         "surname": [
#           "Kopf"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/315113987",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/106907523X/about"
#         },
#         {
#           "collection": {
#             "abbr": "DDB",
#             "name": "Deutsche Digitale Bibliothek",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "id": "http://www.wikidata.org/entity/Q621630"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/106907523X"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4029050-5",
#           "label": "Jurist"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "nameAddition": [
#             "de Reuss"
#           ],
#           "personalName": [
#             "Philippus Henricus"
#           ]
#         },
#         {
#           "forename": [
#             "Philippus Henricus"
#           ],
#           "prefix": [
#             "de"
#           ],
#           "surname": [
#             "Reuss"
#           ]
#         },
#         {
#           "forename": [
#             "Philippus Henricus"
#           ],
#           "prefix": [
#             "de"
#           ],
#           "surname": [
#             "Haberkorn-Reuss"
#           ]
#         },
#         {
#           "forename": [
#             "Philippus Henricus"
#           ],
#           "nameAddition": [
#             "dictus Haberkorn"
#           ],
#           "prefix": [
#             "de"
#           ],
#           "surname": [
#             "Reuss"
#           ]
#         },
#         {
#           "nameAddition": [
#             "von Reuss"
#           ],
#           "personalName": [
#             "Philipp Heinrich"
#           ]
#         },
#         {
#           "forename": [
#             "Philipp Heinrich"
#           ],
#           "prefix": [
#             "von"
#           ],
#           "surname": [
#             "Haberkorn-Reuss"
#           ]
#         }
#       ],
#       "type": [
#         "DifferentiatedPerson",
#         "Person",
#         "AuthorityResource"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Kammergerichtsassessor in Wetzlar"
#       ],
#       "periodOfActivity": [
#         "1752-1772"
#       ],
#       "publication": [
#         "Theses Ex Ivre Vniverso...."
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/1067644539/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2019-11-22T18:10:18.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         }
#       },
#       "gndIdentifier": "1067644539",
#       "id": "https://d-nb.info/gnd/1067644539",
#       "placeOfActivity": [
#         {
#           "id": "https://d-nb.info/gnd/4065878-8",
#           "label": "Wetzlar"
#         }
#       ],
#       "preferredName": "Reuss, Philipp Heinrich von",
#       "variantName": [
#         "Haberkorn-Reuss, Philippus Henricus de",
#         "Haberkorn-Reuss, Philipp Heinrich von",
#         "Reuss, Philippus Henricus de, dictus Haberkorn",
#         "Reuss, Philippus Henricus de",
#         "Philippus Henricus, de Reuss",
#         "Philipp Heinrich, von Reuss"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Philipp Heinrich"
#         ],
#         "prefix": [
#           "von"
#         ],
#         "surname": [
#           "Reuss"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/314870689",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/1067644539/about"
#         },
#         {
#           "collection": {
#             "abbr": "DDB",
#             "name": "Deutsche Digitale Bibliothek",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "id": "http://www.wikidata.org/entity/Q621630"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/1067644539"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4029050-5",
#           "label": "Jurist"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Philipp Heinrich"
#           ],
#           "prefix": [
#             "von"
#           ],
#           "surname": [
#             "Göttfort"
#           ]
#         },
#         {
#           "forename": [
#             "Philippus Henricus"
#           ],
#           "prefix": [
#             "a"
#           ],
#           "surname": [
#             "Gottfart"
#           ]
#         },
#         {
#           "forename": [
#             "..."
#           ],
#           "surname": [
#             "Geffort"
#           ]
#         },
#         {
#           "forename": [
#             "Philippus Heinricus"
#           ],
#           "prefix": [
#             "a"
#           ],
#           "surname": [
#             "Gottfart"
#           ]
#         },
#         {
#           "forename": [
#             "Philippus Heinricus"
#           ],
#           "prefix": [
#             "a"
#           ],
#           "surname": [
#             "Göttfart"
#           ]
#         },
#         {
#           "forename": [
#             "Philipp Heinrich"
#           ],
#           "prefix": [
#             "von"
#           ],
#           "surname": [
#             "Göttfahrt"
#           ]
#         },
#         {
#           "forename": [
#             "Philipp Heinrich"
#           ],
#           "prefix": [
#             "von"
#           ],
#           "surname": [
#             "Gottfarth"
#           ]
#         },
#         {
#           "forename": [
#             "Philipp Heinrich"
#           ],
#           "prefix": [
#             "von"
#           ],
#           "surname": [
#             "Göttfordt"
#           ]
#         },
#         {
#           "forename": [
#             "Philip Heinrich"
#           ],
#           "prefix": [
#             "von"
#           ],
#           "surname": [
#             "Göttfarth"
#           ]
#         }
#       ],
#       "type": [
#         "AuthorityResource",
#         "DifferentiatedPerson",
#         "Person"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)124438741"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "aus Thüringen; Respondent an der Univ. Jena"
#       ],
#       "periodOfActivity": [
#         "1670-1674"
#       ],
#       "publication": [
#         "Beiträger in: Schmertzlichste Trauer-Klagen Welche über das Höchstseligste Absterben Deß ... Hn. Christian von Pölnitz ... - 1670",
#         "Strauch, Johann: Edictum De Alterutro 1. unic. §. 3. C. de Rei uxcoriae actione ... - 1673"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/124438741/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2018-09-14T17:56:15.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplinäre Allgemeinwörter"
#         }
#       },
#       "gndIdentifier": "124438741",
#       "id": "https://d-nb.info/gnd/124438741",
#       "preferredName": "Gottfart, Philipp Heinrich von",
#       "variantName": [
#         "Gottfart, Philippus Heinricus a",
#         "Geffort, ...",
#         "Gottfart, Philippus Henricus a",
#         "Göttfart, Philippus Heinricus a",
#         "Göttfarth, Philip Heinrich von",
#         "Göttfort, Philipp Heinrich von",
#         "Gottfarth, Philipp Heinrich von",
#         "Göttfordt, Philipp Heinrich von",
#         "Göttfahrt, Philipp Heinrich von"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Philipp Heinrich"
#         ],
#         "prefix": [
#           "von"
#         ],
#         "surname": [
#           "Gottfart"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/57546224",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/124438741/about"
#         },
#         {
#           "collection": {
#             "abbr": "DDB",
#             "name": "Deutsche Digitale Bibliothek",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "id": "http://www.wikidata.org/entity/Q621630"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/124438741"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4140768-4",
#           "label": "Bankier"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "dateOfDeath": [
#         "1926"
#       ],
#       "dateOfBirth": [
#         "1844"
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Heinrich Philipp"
#           ],
#           "surname": [
#             "Moriz-Eichborn"
#           ]
#         },
#         {
#           "forename": [
#             "Heinrich Philipp"
#           ],
#           "surname": [
#             "Eichborn"
#           ]
#         }
#       ],
#       "type": [
#         "DifferentiatedPerson",
#         "Person",
#         "AuthorityResource"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)136093272"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-PL",
#           "label": "Polen"
#         },
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Präsident der Industrie- und Handelskammer; Kommissar der königlichen Rentenbank in Breslau"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/136093272/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2008-08-20T08:44:03.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplinäre Allgemeinwörter"
#         }
#       },
#       "gndIdentifier": "136093272",
#       "id": "https://d-nb.info/gnd/136093272",
#       "preferredName": "Eichborn, Heinrich Philipp von",
#       "variantName": [
#         "Eichborn, Heinrich Philipp",
#         "Moriz-Eichborn, Heinrich Philipp"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Heinrich Philipp"
#         ],
#         "prefix": [
#           "von"
#         ],
#         "surname": [
#           "Eichborn"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://isni.org/isni/0000000056112299",
#           "collection": {
#             "id": "http://isni.org"
#           }
#         },
#         {
#           "id": "http://viaf.org/viaf/80496392",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "id": "http://www.wikidata.org/entity/Q55849536",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q2013",
#             "abbr": "WIKIDATA",
#             "publisher": "Wikimedia Foundation Inc.",
#             "icon": "https://www.wikidata.org/static/favicon/wikidata.ico",
#             "name": "Wikidata"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/136093272/about"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "dateOfDeath": [
#         "1863"
#       ],
#       "dateOfBirth": [
#         "1777"
#       ],
#       "type": [
#         "AuthorityResource",
#         "Person",
#         "DifferentiatedPerson"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)116989262"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "titleOfNobility": [
#         {
#           "id": "https://d-nb.info/gnd/4018333-6",
#           "label": "Freiherr"
#         }
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/116989262/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2022-09-21T07:25:47.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplinäre Allgemeinwörter"
#         }
#       },
#       "gndIdentifier": "116989262",
#       "id": "https://d-nb.info/gnd/116989262",
#       "preferredName": "Medem, Heinrich Philipp von",
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Heinrich Philipp"
#         ],
#         "prefix": [
#           "von"
#         ],
#         "surname": [
#           "Medem"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/77081963",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "id": "http://www.wikidata.org/entity/Q94839702",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q2013",
#             "abbr": "WIKIDATA",
#             "publisher": "Wikimedia Foundation Inc.",
#             "icon": "https://www.wikidata.org/static/favicon/wikidata.ico",
#             "name": "Wikidata"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/116989262/about"
#         },
#         {
#           "collection": {
#             "abbr": "DE-611",
#             "name": "Kalliope Verbundkatalog",
#             "publisher": "Staatsbibliothek zu Berlin - Preußischer Kulturbesitz",
#             "icon": "https://kalliope-verbund.info/img/favicon.ico",
#             "id": "https://kalliope-verbund.info"
#           },
#           "id": "https://kalliope-verbund.info/gnd/116989262"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4396366-3",
#           "label": "Kommunalpolitiker"
#         }
#       ],
#       "placeOfBirthAsLiteral": [
#         "Deckbergen"
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "dateOfDeath": [
#         "1976-04-04"
#       ],
#       "placeOfDeathAsLiteral": [
#         "Hannover"
#       ],
#       "dateOfBirth": [
#         "1914-12-11"
#       ],
#       "type": [
#         "DifferentiatedPerson",
#         "Person",
#         "AuthorityResource"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#ZZ",
#           "label": "Land unbekannt"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Bundesverdienstkreuz (1973)."
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/1034903500/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2017-01-16T17:04:02.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#4",
#           "label": "Philosophie"
#         }
#       },
#       "gndIdentifier": "1034903500",
#       "id": "https://d-nb.info/gnd/1034903500",
#       "preferredName": "Hoff, Heinrich",
#       "wikipedia": [
#         {
#           "id": "https://de.wikipedia.org/wiki/Heinrich_Hoff",
#           "label": "https://de.wikipedia.org/wiki/Heinrich_Hoff"
#         }
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Heinrich"
#         ],
#         "surname": [
#           "Hoff"
#         ]
#       },
#       "professionOrOccupationAsLiteral": [
#         "Stadtrat",
#         "Bürgermeister von Ahlem"
#       ],
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/300937150",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "id": "http://www.wikidata.org/entity/Q1597622",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q2013",
#             "abbr": "WIKIDATA",
#             "publisher": "Wikimedia Foundation Inc.",
#             "icon": "https://www.wikidata.org/static/favicon/wikidata.ico",
#             "name": "Wikidata"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/1034903500/about"
#         },
#         {
#           "collection": {
#             "abbr": "dewiki",
#             "name": "Wikipedia (Deutsch)",
#             "publisher": "Wikimedia Foundation Inc.",
#             "icon": "https://de.wikipedia.org/static/favicon/wikipedia.ico",
#             "id": "http://www.wikidata.org/entity/Q48183"
#           },
#           "id": "https://de.wikipedia.org/wiki/Heinrich_Hoff"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "dateOfDeath": [
#         "2019-08-18"
#       ],
#       "dateOfBirth": [
#         "1944-10-08"
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Werner Heinrich"
#           ],
#           "surname": [
#             "Hopf"
#           ]
#         },
#         {
#           "forename": [
#             "Werner H."
#           ],
#           "surname": [
#             "Hopf"
#           ]
#         }
#       ],
#       "type": [
#         "AuthorityResource",
#         "DifferentiatedPerson",
#         "Person"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)123757304"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Schulpsychologe"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/123757304/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2019-10-10T11:25:48.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplinäre Allgemeinwörter"
#         }
#       },
#       "gndIdentifier": "123757304",
#       "id": "https://d-nb.info/gnd/123757304",
#       "preferredName": "Hopf, Werner",
#       "variantName": [
#         "Hopf, Werner H.",
#         "Hopf, Werner Heinrich"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Werner"
#         ],
#         "surname": [
#           "Hopf"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/15309723",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/123757304/about"
#         },
#         {
#           "collection": {
#             "abbr": "DDB",
#             "name": "Deutsche Digitale Bibliothek",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "id": "http://www.wikidata.org/entity/Q621630"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/123757304"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Johann Heinrich"
#           ],
#           "prefix": [
#             "im"
#           ],
#           "surname": [
#             "Hoof"
#           ]
#         },
#         {
#           "forename": [
#             "Joh. Henricus"
#           ],
#           "surname": [
#             "ImHoof"
#           ]
#         },
#         {
#           "forename": [
#             "Johannes Henricus"
#           ],
#           "surname": [
#             "ImHoof"
#           ]
#         }
#       ],
#       "type": [
#         "Person",
#         "AuthorityResource",
#         "DifferentiatedPerson"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-CH",
#           "label": "Europa"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "aus Bern; Respondent"
#       ],
#       "periodOfActivity": [
#         "1660"
#       ],
#       "publication": [
#         "Disputatio De Origine Symboli apostolici ... - 1660"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/1083041762/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2016-02-18T13:29:13.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         }
#       },
#       "gndIdentifier": "1083041762",
#       "id": "https://d-nb.info/gnd/1083041762",
#       "preferredName": "ImHoof, Johann Heinrich",
#       "variantName": [
#         "ImHoof, Johannes Henricus",
#         "ImHoof, Joh. Henricus",
#         "Hoof, Johann Heinrich im"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Johann Heinrich"
#         ],
#         "surname": [
#           "ImHoof"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/121145601894201321514",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/1083041762/about"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4132592-8",
#           "label": "Pfarrer"
#         },
#         {
#           "id": "https://d-nb.info/gnd/7635523-8",
#           "label": "Tierschützer"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "https://d-nb.info/gnd/4536853-3",
#           "label": "Affoltern (Zürich)"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "dateOfDeath": [
#         "1903-10-05"
#       ],
#       "dateOfBirth": [
#         "1822-06-15"
#       ],
#       "placeOfDeath": [
#         {
#           "id": "https://d-nb.info/gnd/4683917-3",
#           "label": "Weiningen (Kanton Zürich)"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "P. H."
#           ],
#           "surname": [
#             "Wolff"
#           ]
#         }
#       ],
#       "type": [
#         "Person",
#         "DifferentiatedPerson",
#         "AuthorityResource"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "gndSubjectCategory": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gnd-sc#3.6p",
#           "label": "Personen zu Kirchengeschichte, Systematischer und Praktischer Theologie, Kirche und Konfession"
#         },
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gnd-sc#25.3p",
#           "label": "Personen zu Zoologie"
#         }
#       ],
#       "oldAuthorityNumber": [
#         "(DE-588a)128361204"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-CH",
#           "label": "Europa"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "1856 Mitbegründer des Zürcher Tierschutzvereins, 1861 des Schweiz. Zentralvereins zum Schutz der Thiere; Zunftmeister der Zürcher Schiffsleutezunft, ab 1871 Präsident der Gesellschaft zur Gründung eines Zoos in Zürich und 1853-1903 als Zürcher Kantonsrat"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/128361204/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2016-06-24T09:11:37.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplinäre Allgemeinwörter"
#         }
#       },
#       "gndIdentifier": "128361204",
#       "id": "https://d-nb.info/gnd/128361204",
#       "placeOfActivity": [
#         {
#           "id": "https://d-nb.info/gnd/4068038-1",
#           "label": "Zürich"
#         }
#       ],
#       "preferredName": "Wolff, Philipp Heinrich",
#       "variantName": [
#         "Wolff, P. H."
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Philipp Heinrich"
#         ],
#         "surname": [
#           "Wolff"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/1062476",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "id": "http://www.wikidata.org/entity/Q110576370",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q2013",
#             "abbr": "WIKIDATA",
#             "publisher": "Wikimedia Foundation Inc.",
#             "icon": "https://www.wikidata.org/static/favicon/wikidata.ico",
#             "name": "Wikidata"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/128361204/about"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Philippus Henricus"
#           ],
#           "surname": [
#             "Braunschmidius"
#           ]
#         }
#       ],
#       "type": [
#         "Person",
#         "DifferentiatedPerson",
#         "AuthorityResource"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)128473363"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "aus Würzburg; Student in Wittenberg"
#       ],
#       "periodOfActivity": [
#         "1652-"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/128473363/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2023-04-18T11:30:44.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         }
#       },
#       "gndIdentifier": "128473363",
#       "id": "https://d-nb.info/gnd/128473363",
#       "preferredName": "Braunschmid, Philipp Heinrich",
#       "variantName": [
#         "Braunschmidius, Philippus Henricus"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Philipp Heinrich"
#         ],
#         "surname": [
#           "Braunschmid"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://isni.org/isni/0000000017494888",
#           "collection": {
#             "id": "http://isni.org"
#           }
#         },
#         {
#           "id": "http://viaf.org/viaf/74906075",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/128473363/about"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4138343-6",
#           "label": "Verleger"
#         },
#         {
#           "id": "https://d-nb.info/gnd/4130948-0",
#           "label": "Buchhändler"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "affiliationAsLiteral": [
#         "Verlag der Privilegirt. Perrenonischen Buchhandl. (Hamm)",
#         "Privilegirte Perrenonische Buchhandlung (Hamm)",
#         "Perrenonsche Buchhandlung (Münster)",
#         "Privilegirt. Perrenonische Buchhandl. (Hamm)"
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Philippe Henry"
#           ],
#           "surname": [
#             "Perrenon"
#           ]
#         },
#         {
#           "forename": [
#             "Philippus Henricus"
#           ],
#           "surname": [
#             "Perrenonius"
#           ]
#         },
#         {
#           "forename": [
#             "Phil. Heinr."
#           ],
#           "surname": [
#             "Perrenon"
#           ]
#         },
#         {
#           "forename": [
#             "Philippus Henricus"
#           ],
#           "surname": [
#             "Perrenon"
#           ]
#         },
#         {
#           "forename": [
#             "Philipp Heinr."
#           ],
#           "surname": [
#             "Perrenon"
#           ]
#         }
#       ],
#       "type": [
#         "AuthorityResource",
#         "DifferentiatedPerson",
#         "Person"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)116082151"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Dokument in Fürstbistum Münster, Kabinettsregistratur,  Nr. 3276: Erlaubnis für Franz Wilhelm Joseph Metternich  aus Köln und Philipp Heinrich Perrenon zur Eröffnung einer  Buchhandlung in Münster; Aufnahme des Franz Friedrich  Platvoet in die Perrenonsche Buchhandlung, 1768, 1791; 1798 bis 1803 Buchhandlung im Besitz der Brüder Franz und Anton Platvoet; 1803 übernahm Joseph Heinrich Coppenrath die Perrenonsche Buchhandlung"
#       ],
#       "affiliation": [
#         {
#           "id": "https://d-nb.info/gnd/5076969-8",
#           "label": "Buchhändler Philipp Heinrich Perrenon (Münster, Westfalen; Hamm)"
#         }
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/116082151/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2020-09-18T15:42:04.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplinäre Allgemeinwörter"
#         }
#       },
#       "gndIdentifier": "116082151",
#       "id": "https://d-nb.info/gnd/116082151",
#       "placeOfActivity": [
#         {
#           "id": "https://d-nb.info/gnd/4035206-7",
#           "label": "Leipzig"
#         },
#         {
#           "id": "https://d-nb.info/gnd/4043974-4",
#           "label": "Osnabrück"
#         },
#         {
#           "id": "https://d-nb.info/gnd/4040608-8",
#           "label": "Münster (Westf)"
#         },
#         {
#           "id": "https://d-nb.info/gnd/4023168-9",
#           "label": "Hamm (Westf)"
#         }
#       ],
#       "preferredName": "Perrenon, Philipp Heinrich",
#       "variantName": [
#         "Perrenon, Philipp Heinr.",
#         "Perrenon, Philippus Henricus",
#         "Perrenonius, Philippus Henricus",
#         "Perrenon, Phil. Heinr.",
#         "Perrenon, Philippe Henry"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Philipp Heinrich"
#         ],
#         "surname": [
#           "Perrenon"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://id.loc.gov/rwo/agents/no2021014447",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q13219454",
#             "abbr": "LC",
#             "publisher": "Library of Congress",
#             "icon": "http://www.loc.gov/favicon.ico",
#             "name": "NACO Authority File"
#           }
#         },
#         {
#           "id": "http://viaf.org/viaf/306414516",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/116082151/about"
#         },
#         {
#           "collection": {
#             "abbr": "DE-611",
#             "name": "Kalliope Verbundkatalog",
#             "publisher": "Staatsbibliothek zu Berlin - Preußischer Kulturbesitz",
#             "icon": "https://kalliope-verbund.info/img/favicon.ico",
#             "id": "https://kalliope-verbund.info"
#           },
#           "id": "https://kalliope-verbund.info/gnd/116082151"
#         },
#         {
#           "collection": {
#             "abbr": "DDB",
#             "name": "Deutsche Digitale Bibliothek",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "id": "http://www.wikidata.org/entity/Q621630"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/116082151"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
# ...
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/14324308X/about"
#         },
#         {
#           "collection": {
#             "abbr": "DDB",
#             "name": "Deutsche Digitale Bibliothek",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "id": "http://www.wikidata.org/entity/Q621630"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/14324308X"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4058167-6",
#           "label": "Student"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Johannes Henricus Philippus"
#           ],
#           "surname": [
#             "Fenner"
#           ]
#         }
#       ],
#       "type": [
#         "DifferentiatedPerson",
#         "Person",
#         "AuthorityResource"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)1011992973"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "periodOfActivity": [
#         "1750"
#       ],
#       "publication": [
#         "Articulos Quosdam Generales Sive Dissertationis, qua theoria actionum humanarum exhibitur ... - 1750"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/1011992973/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2020-12-11T16:19:24.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         }
#       },
#       "gndIdentifier": "1011992973",
#       "id": "https://d-nb.info/gnd/1011992973",
#       "placeOfActivity": [
#         {
#           "id": "https://d-nb.info/gnd/4021477-1",
#           "label": "Göttingen"
#         }
#       ],
#       "preferredName": "Fenner, Johann Heinrich Philipp",
#       "variantName": [
#         "Fenner, Johannes Henricus Philippus"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Johann Heinrich Philipp"
#         ],
#         "surname": [
#           "Fenner"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/171031970",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/1011992973/about"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4029050-5",
#           "label": "Jurist"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "type": [
#         "Person",
#         "DifferentiatedPerson",
#         "AuthorityResource"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Promotion an der Rechtswissenschaftlichen Fakultät der Westfälischen Wilhelms-Universität Münster"
#       ],
#       "affiliation": [
#         {
#           "id": "https://d-nb.info/gnd/1057933643",
#           "label": "Oppenhoff & Partner Rechtsanwälte Steuerberater mbH"
#         }
#       ],
#       "academicDegree": [
#         "Dr."
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/1247763528/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2022-12-09T09:11:41.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         }
#       },
#       "gndIdentifier": "1247763528",
#       "id": "https://d-nb.info/gnd/1247763528",
#       "preferredName": "Heinrichs, Philipp",
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Philipp"
#         ],
#         "surname": [
#           "Heinrichs"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/33163994567501832369",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/1247763528/about"
#         },
#         {
#           "collection": {
#             "abbr": "DDB",
#             "name": "Deutsche Digitale Bibliothek",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "id": "http://www.wikidata.org/entity/Q621630"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/1247763528"
#         }
#       ]
#     },
#     {
#       "placeOfBirthAsLiteral": [
#         "Gronau <Leine>"
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "Männlich"
#         }
#       ],
#       "dateOfDeath": [
#         "1921-08-15"
#       ],
#       "placeOfDeathAsLiteral": [
#         "Radbruch"
#       ],
#       "dateOfBirth": [
#         "1848-04-04"
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Heinrich"
#           ],
#           "surname": [
#             "Ast"
#           ]
#         },
#         {
#           "personalName": [
#             "Schäfer Ast"
#           ]
#         }
#       ],
#       "type": [
#         "DifferentiatedPerson",
#         "AuthorityResource",
#         "Person"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#ZZ",
#           "label": "Land unbekannt"
#         }
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/1033719714/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2017-11-29T17:37:46.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         }
#       },
#       "gndIdentifier": "1033719714",
#       "id": "https://d-nb.info/gnd/1033719714",
#       "preferredName": "Ast, Heinrich Philipp",
#       "variantName": [
#         "Ast, Heinrich",
#         "Schäfer Ast"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Heinrich Philipp"
#         ],
#         "surname": [
#           "Ast"
#         ]
#       },
#       "professionOrOccupationAsLiteral": [
#         "Naturheilkundiger",
#         "Schäfer"
#       ],
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/299985564",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/1033719714/about"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Johannes Philippus"
#           ],
#           "surname": [
#             "Hofius"
#           ]
#         }
#       ],
#       "type": [
#         "DifferentiatedPerson",
#         "Person",
#         "AuthorityResource"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)1018302344"
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Student der Theologie und der Philosophie; Respondent an der Hohen Schule in Herborn"
#       ],
#       "periodOfActivity": [
#         "1671-1673"
#       ],
#       "publication": [
#         "Samuel Andreae: Disputatio Physica De Tonitru. - 1673",
#         "Samuel Andreae: Disputatio Metaphysica de Signo et Signato. - 1671",
#         "Samuel Andreae: Oratio de Incarnatione Dominicae Mysterio. - 1672"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/1018302344/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2011-12-22T14:29:07.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         }
#       },
#       "gndIdentifier": "1018302344",
#       "id": "https://d-nb.info/gnd/1018302344",
#       "preferredName": "Hof, Johann Philipp",
#       "variantName": [
#         "Hofius, Johannes Philippus"
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Johann Philipp"
#         ],
#         "surname": [
#           "Hof"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/221061883",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/1018302344/about"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4046517-2",
#           "label": "Politiker"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "https://d-nb.info/gnd/4037372-1",
#           "label": "Mannheim"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "dateOfDeath": [
#         "1891-05-07"
#       ],
#       "dateOfBirth": [
#         "1804-07-12"
#       ],
#       "placeOfDeath": [
#         {
#           "id": "https://d-nb.info/gnd/4037372-1",
#           "label": "Mannheim"
#         }
#       ],
#       "type": [
#         "Person",
#         "AuthorityResource",
#         "DifferentiatedPerson"
#       ],
#       "@context": "http://lobid.org/gnd/context.jsonld",
#       "gndSubjectCategory": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gnd-sc#00p",
#           "label": "Sachlich nicht klassifizierbare Personen"
#         }
#       ],
#       "oldAuthorityNumber": [
#         "(DE-588a)1012273687"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Konditor, Landtagsabgeordneter"
#       ],
#       "describedBy": {
#         "id": "https://d-nb.info/gnd/1012273687/about",
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2017-01-04T17:04:55.000",
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#4",
#           "label": "Philosophie"
#         }
#       },
#       "gndIdentifier": "1012273687",
#       "id": "https://d-nb.info/gnd/1012273687",
#       "preferredName": "Hoff, Karl Heinrich",
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Karl Heinrich"
#         ],
#         "surname": [
#           "Hoff"
#         ]
#       },
#       "professionOrOccupationAsLiteral": [
#         "Landtagsabgeordneter",
#         "Konditor",
#         "Abgeordneter"
#       ],
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/170947087",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF",
#             "publisher": "OCLC",
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)"
#           }
#         },
#         {
#           "id": "http://www.wikidata.org/entity/Q94765147",
#           "collection": {
#             "id": "http://www.wikidata.org/entity/Q2013",
#             "abbr": "WIKIDATA",
#             "publisher": "Wikimedia Foundation Inc.",
#             "icon": "https://www.wikidata.org/static/favicon/wikidata.ico",
#             "name": "Wikidata"
#           }
#         },
#         {
#           "collection": {
#             "abbr": "DNB",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "id": "http://www.wikidata.org/entity/Q36578"
#           },
#           "id": "https://d-nb.info/gnd/1012273687/about"
#         }
#       ]
#     }
#   ]
# }
